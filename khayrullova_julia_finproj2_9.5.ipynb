# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#План-работ" data-toc-modified-id="План-работ-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>План работ</a></span></li><li><span><a href="#Технологический-процесс" data-toc-modified-id="Технологический-процесс-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Технологический процесс</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Проверка-расчёта-обогащения-(rougher.output.recovery)" data-toc-modified-id="Проверка-расчёта-обогащения-(rougher.output.recovery)-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверка расчёта обогащения (<code>rougher.output.recovery</code>)</a></span></li><li><span><a href="#Признаки,-недоступные-в-тестовой-выборке." data-toc-modified-id="Признаки,-недоступные-в-тестовой-выборке.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Признаки, недоступные в тестовой выборке.</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Наименования-столбцов" data-toc-modified-id="Наименования-столбцов-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Наименования столбцов</a></span></li><li><span><a href="#Пропуски-данных" data-toc-modified-id="Пропуски-данных-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Пропуски данных</a></span></li><li><span><a href="#Аномалии" data-toc-modified-id="Аномалии-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Аномалии</a></span></li><li><span><a href="#Корреляции-#TODO" data-toc-modified-id="Корреляции-#TODO-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Корреляции #TODO</a></span></li><li><span><a href="#features,-target" data-toc-modified-id="features,-target-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>features, target</a></span></li><li><span><a href="#Масштабирование" data-toc-modified-id="Масштабирование-1.4.6"><span class="toc-item-num">1.4.6&nbsp;&nbsp;</span>Масштабирование</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Концентрация-металлов" data-toc-modified-id="Концентрация-металлов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Концентрация металлов</a></span><ul class="toc-item"><li><span><a href="#Au-Золото" data-toc-modified-id="Au-Золото-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Au Золото</a></span></li><li><span><a href="#Ag-Серебро" data-toc-modified-id="Ag-Серебро-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Ag Серебро</a></span></li><li><span><a href="#Pb-Свинец" data-toc-modified-id="Pb-Свинец-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Pb Свинец</a></span></li></ul></li><li><span><a href="#Размеры-гранул-сырья" data-toc-modified-id="Размеры-гранул-сырья-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Размеры гранул сырья</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#Суммарная-концентрация-всех-веществ" data-toc-modified-id="Суммарная-концентрация-всех-веществ-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Суммарная концентрация всех веществ</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Функция-для-sMAPE" data-toc-modified-id="Функция-для-sMAPE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция для sMAPE</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#Обучение-моделей,-кросс-валидация" data-toc-modified-id="Обучение-моделей,-кросс-валидация-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Обучение моделей, кросс-валидация</a></span><ul class="toc-item"><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>LinearRegression</a></span></li></ul></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span><ul class="toc-item"><li><span><a href="#Ridge" data-toc-modified-id="Ridge-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Ridge</a></span></li></ul></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span><ul class="toc-item"><li><span><a href="#KNeighborsRegressor" data-toc-modified-id="KNeighborsRegressor-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>KNeighborsRegressor</a></span></li><li><span><a href="#SVR" data-toc-modified-id="SVR-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>SVR</a></span></li></ul></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#-Комментарий-ревьюера-v1" data-toc-modified-id="-Комментарий-ревьюера-v1-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span> Комментарий ревьюера v1</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span><ul class="toc-item"><li><span><a href="#-Итоговый-комментарий" data-toc-modified-id="-Итоговый-комментарий-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span> Итоговый комментарий</a></span></li><li><span><a href="#-Комментарий-ревьюера-v2" data-toc-modified-id="-Комментарий-ревьюера-v2-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span> Комментарий ревьюера v2</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Обогащение золотой руды
#
# Нужно подготовить прототип модели машинного обучения для компании, разрабатывающей решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. В нашем распоряжении данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.

# %% [markdown]
# Данные находятся в трёх файлах:
# - gold_recovery_train_new.csv — обучающая выборка;
# - gold_recovery_test_new.csv — тестовая выборка;
# - gold_recovery_full_new.csv — исходные данные.
#
# Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
#
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# В нашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, проверим их на корректность.

# %% [markdown]
# ### План работ

# %% [markdown]
# 1. Подготовим данные
# <br>    1.1. Откроем файлы и изучим их.
# <br>    1.2. Проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака rougher.output.recovery. Найдем MAE между нашими расчётами и значением признака. Опишем выводы.
# <br>    1.3. Проанализируем признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?
# <br>    1.4. Проведем предобработку данных.
# 2. Проанализируем данные
# <br>    2.1. Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишем выводы.
# <br>    2.2. Сравним распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
# <br>    2.3. Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
# 3. Построим модель
# <br>    3.1. Напишем функцию для вычисления итоговой sMAPE.
# <br>    3.2. Обучим разные модели и оценим их качество кросс-валидацией. Выберем лучшую модель и проверим её на тестовой выборке. Опишем выводы.

# %% [markdown]
# ### Технологический процесс

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Описание данных

# %% [markdown]
# **Технологический процесс**
# <br>Rougher feed — исходное сырье
# <br>Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# <br>Xanthate \*\*— ксантогенат (промотер, или активатор флотации);
# <br>Sulphate — сульфат (на данном производстве сульфид натрия);
# <br>Depressant — депрессант (силикат натрия).
# <br>Rougher process (англ. «грубый процесс») — флотация
# <br>Rougher tails — отвальные хвосты
# <br>Float banks — флотационная установка
# <br>Cleaner process — очистка
# <br>Rougher Au — черновой концентрат золота
# <br>Final Au — финальный концентрат золота
#
# **Параметры этапов**
# <br>air amount — объём воздуха
# <br>fluid levels — уровень жидкости
# <br>feed size — размер гранул сырья
# <br>feed rate — скорость подачи
#
# **Наименование признаков**
# <br>Наименование признаков должно быть такое:
# <br>[этап].[тип_параметра].[название_параметра]
# <br>Пример: rougher.input.feed_ag
#
# Возможные значения для блока [этап]:
# <br>rougher — флотация
# <br>primary_cleaner — первичная очистка
# <br>secondary_cleaner — вторичная очистка
# <br>final — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
# <br>input — параметры сырья
# <br>output — параметры продукта
# <br>state — параметры, характеризующие текущее состояние этапа
# <br>calculation — расчётные характеристики

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Загрузка данных

# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# import sklearn as sk
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
#from sklearn.experimental import enable_halving_search_cv 
#from sklearn.model_selection import HalvingGridSearchCV
# from sklearn.metrics import mean_squared_error
# from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# from sklearn.utils import shuffle
import warnings
from inspect import getmembers, isfunction
#from random import seed, random
#import statistics

# %%
dt.datetime.today().strftime("%d.%m.%Y %H:%M")
# Out:
# '26.06.2022 19:26'

# %%
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
### warnings.filterwarnings("ignore", category=SettingWithCopyWarning)

# %%
pth1 = '/datasets/'
pth2 = ''
if os.path.exists(pth1+'gold_recovery_train_new.csv'):
    df_train = pd.read_csv(pth1+'gold_recovery_train_new.csv')
    df_test = pd.read_csv(pth1+'gold_recovery_test_new.csv')
    df_full = pd.read_csv(pth1+'gold_recovery_full_new.csv')
elif os.path.exists(pth2+'gold_recovery_train_new.csv'):
    df_train = pd.read_csv(pth2+'gold_recovery_train_new.csv')
    df_test = pd.read_csv(pth2+'gold_recovery_test_new.csv')
    df_full = pd.read_csv(pth2+'gold_recovery_full_new.csv')
else:
    print('Something is wrong')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
# date                                                  14149 non-null object
# final.output.concentrate_ag                           14148 non-null float64
# final.output.concentrate_pb                           14148 non-null float64
# final.output.concentrate_sol                          13938 non-null float64
# final.output.concentrate_au                           14149 non-null float64
# final.output.recovery                                 14149 non-null float64
# final.output.tail_ag                                  14149 non-null float64
# final.output.tail_pb                                  14049 non-null float64
# final.output.tail_sol                                 14144 non-null float64
# final.output.tail_au                                  14149 non-null float64
# primary_cleaner.input.sulfate                         14129 non-null float64
# ...

# %%
df_train.head(2)
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  ...  \
# 0              0.895447              16.904297              2.143149  ...
# 1              0.927452              16.634514              2.224930  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
#
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
# date                                          5290 non-null object
# primary_cleaner.input.sulfate                 5286 non-null float64
# primary_cleaner.input.depressant              5285 non-null float64
# primary_cleaner.input.feed_size               5290 non-null float64
# primary_cleaner.input.xanthate                5286 non-null float64
# primary_cleaner.state.floatbank8_a_air        5290 non-null float64
# primary_cleaner.state.floatbank8_a_level      5290 non-null float64
# primary_cleaner.state.floatbank8_b_air        5290 non-null float64
# primary_cleaner.state.floatbank8_b_level      5290 non-null float64
# primary_cleaner.state.floatbank8_c_air        5290 non-null float64
# primary_cleaner.state.floatbank8_c_level      5290 non-null float64
# primary_cleaner.state.floatbank8_d_air        5290 non-null float64
# ...

# %%
df_test.head(2)
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                             8.08
# 1                         14.987471                             8.08
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# 1                        0.990469                             1398.777912
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -500.225577
# 1                               -500.057435
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1399.144926
# 1                             1398.055362
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -499.919735
# ...

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
# date                                                  19439 non-null object
# final.output.concentrate_ag                           19438 non-null float64
# final.output.concentrate_pb                           19438 non-null float64
# final.output.concentrate_sol                          19228 non-null float64
# final.output.concentrate_au                           19439 non-null float64
# final.output.recovery                                 19439 non-null float64
# final.output.tail_ag                                  19438 non-null float64
# final.output.tail_pb                                  19338 non-null float64
# final.output.tail_sol                                 19433 non-null float64
# final.output.tail_au                                  19439 non-null float64
# primary_cleaner.input.sulfate                         19415 non-null float64
# ...

# %%
df_full.head(2)
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  ...  \
# 0              0.895447              16.904297              2.143149  ...
# 1              0.927452              16.634514              2.224930  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
#
# ...

# %% [markdown]
# В обучающих данных 87 столбцов, в тестовых - 53.
#
# Некоторые параметры недоступны, потому что замеряются и/или
# рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют
# некоторые признаки, которые могут быть в обучающей. Также в тестовом
# наборе нет целевых признаков. Исходный датасет содержит обучающую и тестовую выборки со всеми
# признаками.

# %% [markdown]
# ### Проверка расчёта обогащения (`rougher.output.recovery`)
# Проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака `rougher.output.recovery`. Найдём MAE между нашими расчётами и значением признака. Опишем
# выводы.

# %%
df_tmp = df_train[['rougher.input.feed_au',
                   'rougher.output.concentrate_au',
                   'rougher.output.tail_au',
                   'rougher.output.recovery',
                   ]]
df_tmp.head(3)
# Out:
#    rougher.input.feed_au  rougher.output.concentrate_au  \
# 0               6.486150                      19.793808
# 1               6.478583                      20.050975
# 2               6.362222                      19.737170
#
#    rougher.output.tail_au  rougher.output.recovery
# 0                1.170244                87.107763
# 1                1.184827                86.843261
# 2                1.162562                86.842308

# %%
df_tmp.columns = ['F', 'C', 'T', 'recovery']#, 'calculated_recovery']

# %%
# df_tmp_sample = df_tmp.sample(frac=0.05)
# df_tmp_sample['calculated_recovery'] = (df_tmp['C'] * (df_tmp['F'] - df_tmp['T'])) / (df_tmp['F'] * (df_tmp['C'] - df_tmp['T'])) * 100  # %
# df_tmp_sample.head(5)

df_tmp.loc[:,'calculated_recovery'] = (df_tmp['C'] * (df_tmp['F'] - df_tmp['T'])
                                      ) / (df_tmp['F'] * (df_tmp['C'] - df_tmp['T'])) * 100  # %

df_train.loc[:,'rougher.output.calculated_recovery'] = df_tmp['calculated_recovery']

df_tmp.head(5)
# Out:
# C:\Users\skysh\.conda\envs\praktikum\lib\site-packages\pandas\core\indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\skysh\.conda\envs\praktikum\lib\site-packages\pandas\core\indexing.py:576: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
#           F          C         T   recovery  calculated_recovery
# 0  6.486150  19.793808  1.170244  87.107763            87.107763
# ...

# %%
mae_tmp = mean_absolute_error(df_tmp['calculated_recovery'], df_tmp['recovery'])
mae_tmp
# Out:
# 9.682896147825551e-15

# %% [markdown]
# Есть очень незначительное расхождение между расчётным recovery и имеющимся. Думаю, им можно пренебречь, т.к. полученное MAE = 10<sup>-15</sup> - довольно мало.

# %% [markdown]
# ### Признаки, недоступные в тестовой выборке.
# Проанализируем признаки, недоступные в тестовой выборке. Что это за параметры, к какому типу относятся.

# %%
#type(df_train.columns)
pd.DataFrame(list(set(df_train.columns.tolist()) - set(df_test.columns.tolist())),
            columns=['col']).sort_values(
    by='col', ascending=False).reset_index(drop=True)
# Out:
#                                                   col
# 0                   secondary_cleaner.output.tail_sol
# 1                    secondary_cleaner.output.tail_pb
# 2                    secondary_cleaner.output.tail_au
# 3                    secondary_cleaner.output.tail_ag
# 4                             rougher.output.tail_sol
# 5                              rougher.output.tail_pb
# 6                              rougher.output.tail_au
# 7                              rougher.output.tail_ag
# 8                             rougher.output.recovery
# 9                      rougher.output.concentrate_sol
# 10                      rougher.output.concentrate_pb
# 11                      rougher.output.concentrate_au
# 12                      rougher.output.concentrate_ag
# 13                 rougher.output.calculated_recovery
# 14      rougher.calculation.sulfate_to_au_concentrate
# 15  rougher.calculation.floatbank11_sulfate_to_au_...
# ...

# %% [markdown]
# Как видим, в тестовой выборке недоступны все параметры продукта на всех этапах (`output`), а также расчётные характеристики (`calculation`) флотации (`rougher`).

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Наименования столбцов
# Переименуем для удобства названия столбцов, заменив '.' на '\_' (чтобы можно было обращаться через . к столбцам).

# %%
df_train.columns = [c.replace('.', '_') for c in df_train.columns.tolist()]
df_train.columns.tolist()[:3]
# Out:
# ['date', 'final_output_concentrate_ag', 'final_output_concentrate_pb']

# %%
df_test.columns = [c.replace('.', '_') for c in df_test.columns.tolist()]
df_test.columns.tolist()[:3]
# Out:
# ['date', 'primary_cleaner_input_sulfate', 'primary_cleaner_input_depressant']

# %%
df_full.columns = [c.replace('.', '_') for c in df_full.columns.tolist()]
df_full.columns.tolist()[:3]
# Out:
# ['date', 'final_output_concentrate_ag', 'final_output_concentrate_pb']

# %% [markdown]
# #### Пропуски данных

# %%
pd.DataFrame( df_train.columns.tolist(), columns=['col'] ).query(
    'col.str.contains("recovery")', engine='python').sort_values(
    by='col', ascending=True).reset_index(drop=True)
# Out:
#                                   col
# 0               final_output_recovery
# 1  rougher_output_calculated_recovery
# 2             rougher_output_recovery

# %%
df_train.query('rougher_output_recovery != rougher_output_recovery').head(2)
# Out:
# Empty DataFrame
# ...

# %%
df_train.query('final_output_recovery != final_output_recovery').head(2)
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# Пропусков целевых признаков в обучающих данных нет.

# %% [markdown]
# Добавим в тестовую выборку целевые признаки из выборки full для того, чтобы потом можно было оценить результаты тестирования.

# %%
df_test.head(2)
# Out:
#                   date  primary_cleaner_input_sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
#
#    primary_cleaner_input_depressant  primary_cleaner_input_feed_size  \
# 0                         14.993118                             8.08
# 1                         14.987471                             8.08
#
#    primary_cleaner_input_xanthate  primary_cleaner_state_floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# 1                        0.990469                             1398.777912
#
#    primary_cleaner_state_floatbank8_a_level  \
# 0                               -500.225577
# 1                               -500.057435
#
#    primary_cleaner_state_floatbank8_b_air  \
# 0                             1399.144926
# 1                             1398.055362
#
#    primary_cleaner_state_floatbank8_b_level  \
# 0                               -499.919735
# ...

# %%
df_full.query('date in ["2016-09-01 00:59:59", "2016-09-01 01:59:59"]')[
    ['primary_cleaner_input_sulfate','primary_cleaner_input_depressant',
     'primary_cleaner_input_feed_size','rougher_output_recovery', 'final_output_recovery']]
# Out:
#       primary_cleaner_input_sulfate  primary_cleaner_input_depressant  \
# 4682                     210.800909                         14.993118
# 4683                     215.392455                         14.987471
#
#       primary_cleaner_input_feed_size  rougher_output_recovery  \
# 4682                             8.08                89.993421
# 4683                             8.08                88.089657
#
#       final_output_recovery
# 4682              70.273583
# 4683              68.910432

# %%
df_full['date'].value_counts(dropna=False).sort_index(ascending=True)
# Out:
# 2016-01-15 00:00:00    1
# 2016-01-15 01:00:00    1
# 2016-01-15 02:00:00    1
# 2016-01-15 03:00:00    1
# 2016-01-15 04:00:00    1
#                       ..
# 2018-08-18 06:59:59    1
# 2018-08-18 07:59:59    1
# 2018-08-18 08:59:59    1
# 2018-08-18 09:59:59    1
# 2018-08-18 10:59:59    1
# Name: date, Length: 19439, dtype: int64

# %%
# df_train.set_index('date', inplace=True)
df_test.set_index('date', inplace=True)
df_test.head(1)
# Out:
#                      primary_cleaner_input_sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
#
#                      primary_cleaner_input_depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
#
#                      primary_cleaner_input_feed_size  \
# date
# 2016-09-01 00:59:59                             8.08
#
#                      primary_cleaner_input_xanthate  \
# date
# 2016-09-01 00:59:59                        1.005021
#
#                      primary_cleaner_state_floatbank8_a_air  \
# date
# 2016-09-01 00:59:59                             1398.981301
#
#                      primary_cleaner_state_floatbank8_a_level  \
# date
# 2016-09-01 00:59:59                               -500.225577
#
#                      primary_cleaner_state_floatbank8_b_air  \
# date
# 2016-09-01 00:59:59                             1399.144926
#
#                      primary_cleaner_state_floatbank8_b_level  \
# date
# ...

# %%
df_full.set_index('date', inplace=True)
df_full.head(1)
# Out:
#                      final_output_concentrate_ag  final_output_concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
#
#                      final_output_concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
#
#                      final_output_concentrate_au  final_output_recovery  \
# date
# 2016-01-15 00:00:00                     42.19202              70.541216
#
#                      final_output_tail_ag  final_output_tail_pb  \
# date
# 2016-01-15 00:00:00             10.411962              0.895447
#
#                      final_output_tail_sol  final_output_tail_au  \
# date
# 2016-01-15 00:00:00              16.904297              2.143149
#
#                      primary_cleaner_input_sulfate  ...  \
# date                                                ...
# 2016-01-15 00:00:00                     127.092003  ...
#
#                      secondary_cleaner_state_floatbank4_a_air  \
# date
# ...

# %%
df_test.loc[:,'rougher_output_recovery'
           ] = df_full.loc[df_test.index,'rougher_output_recovery']
df_test.loc[:,'final_output_recovery'
           ] = df_full.loc[df_test.index,'final_output_recovery']
df_test.head(2)
# Out:
#                      primary_cleaner_input_sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
# 2016-09-01 01:59:59                     215.392455
#
#                      primary_cleaner_input_depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
# 2016-09-01 01:59:59                         14.987471
#
#                      primary_cleaner_input_feed_size  \
# date
# 2016-09-01 00:59:59                             8.08
# 2016-09-01 01:59:59                             8.08
#
#                      primary_cleaner_input_xanthate  \
# date
# 2016-09-01 00:59:59                        1.005021
# 2016-09-01 01:59:59                        0.990469
#
#                      primary_cleaner_state_floatbank8_a_air  \
# date
# 2016-09-01 00:59:59                             1398.981301
# 2016-09-01 01:59:59                             1398.777912
#
#                      primary_cleaner_state_floatbank8_a_level  \
# date
# ...

# %% [markdown]
# Заполним пропуски в обучающих данных методом `ffill`, т.к. процедура очистки идёт последовательно во времени, и данные отсортированы по дате.
#
# Нули здесь являются по смыслу тоже пропусками, поэтому их сначала заменим на NaN, чтобы потом тоже заполнить значениями.

# %%
df_train.where(df_train != 0, other=np.nan, inplace=True)
# df_train.head(10)

# %%
df_train.isna().sum().sum()
# Out:
# 10018

# %%
df_train.fillna(method='ffill', inplace=True)
df_train.isna().sum().sum()
# Out:
# 0

# %%
df_test.where(df_train != 0, other=np.nan, inplace=True)
df_test.isna().sum().sum()
# Out:
# 90

# %%
df_test.fillna(method='ffill', inplace=True)
df_test.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# #### Аномалии

# %%
len(df_train)
# Out:
# 14149

# %%
for col in df_test.columns.tolist()[1:]:
#     print('\n', col, ':')
    tmp = df_train[col]
    q0 = tmp.quantile(q=0.00075)
    q9 = tmp.quantile(q=0.99925)
    q1 = tmp.quantile(q=0.25)
    q3 = tmp.quantile(q=0.75)
    radius = (q3 - q1) * 1.5
    q_min = min(q1 - radius, q0)
    q_max = max(q3 + radius, q9)
#     print(q_min)
#     print(q_max)
#     print(df_train[ (df_train[col] > q_max) | (df_train[col] < q_min) ][col].count())
    df_train = df_train[ (df_train[col] <= q_max) & (df_train[col] >= q_min) ]

len(df_train)
# Out:
# 13433

# %%
df_train.reset_index(drop=True, inplace=True)
# df_train.set_index(pd.Index(data=range(len(df_train)), name='ind'), inplace=True)
df_test.reset_index(drop=True, inplace=True)
# df_test.set_index(pd.Index(data=range(len(df_test)), name='ind'), inplace=True)

# %% [markdown]
# #### Корреляции #TODO

# %%
# cor = df_test.corr()
# cor
# mask_1 = np.triu(cor)
# sns.heatmap(cor, mask=mask_1, center=0, vmin=-0.08, vmax=0.08, annot=True, fmt='.2g', cbar=False);  #

# %%
cols = df_test.columns.tolist()

for i in range(df_test.shape[1]):
    for j in range(i,df_test.shape[1]):
        col1 = cols[i]
        col2 = cols[j]
        c = df_train[col1].corr(df_train[col2])
        if (i != j) and (c > 0.9):
            print(f"corr(, {col1}, {col2}): {c:2.4f}")
# Out:
# corr(, primary_cleaner_state_floatbank8_a_air, primary_cleaner_state_floatbank8_b_air): 0.9439
# corr(, primary_cleaner_state_floatbank8_a_air, primary_cleaner_state_floatbank8_c_air): 0.9478
# corr(, primary_cleaner_state_floatbank8_a_level, primary_cleaner_state_floatbank8_b_level): 0.9832
# corr(, primary_cleaner_state_floatbank8_a_level, primary_cleaner_state_floatbank8_c_level): 0.9740
# corr(, primary_cleaner_state_floatbank8_b_air, primary_cleaner_state_floatbank8_c_air): 0.9508
# corr(, primary_cleaner_state_floatbank8_b_level, primary_cleaner_state_floatbank8_c_level): 0.9770
# corr(, rougher_input_floatbank10_xanthate, rougher_input_floatbank11_xanthate): 0.9125
# corr(, rougher_state_floatbank10_b_air, rougher_state_floatbank10_c_air): 0.9499
# corr(, rougher_state_floatbank10_b_air, rougher_state_floatbank10_d_air): 0.9282
# corr(, rougher_state_floatbank10_b_level, rougher_state_floatbank10_c_level): 0.9884
# ...

# %% [markdown]
# *Наверно не следует добавлять в features часть столбцов, у которых высокая корреляция с другими. Сделаю это в следующей итерации проекта, возможно. Сейчас не успеваю.*

# %% [markdown]
# #### features, target

# %%
features_train = []
target_train = []
features_test = []
target_test = []

columns = [['rougher_input_feed_ag',
        'rougher_input_feed_pb',
        'rougher_input_feed_rate',
        'rougher_input_feed_size',
        'rougher_input_feed_sol',
        'rougher_input_feed_au',
        'rougher_input_floatbank10_sulfate',
        'rougher_input_floatbank10_xanthate',
        'rougher_input_floatbank11_sulfate',
        'rougher_input_floatbank11_xanthate',
        'rougher_state_floatbank10_a_air',
        'rougher_state_floatbank10_a_level',
        'rougher_state_floatbank10_b_air',
        'rougher_state_floatbank10_b_level',
        'rougher_state_floatbank10_c_air',
        'rougher_state_floatbank10_c_level',
        'rougher_state_floatbank10_d_air',
        'rougher_state_floatbank10_d_level',
        'rougher_state_floatbank10_e_air',
        'rougher_state_floatbank10_e_level',
        'rougher_state_floatbank10_f_air',
        'rougher_state_floatbank10_f_level',],
           
           ['primary_cleaner_input_sulfate',
        'primary_cleaner_input_depressant',
        'primary_cleaner_input_feed_size',
        'primary_cleaner_input_xanthate',
        'primary_cleaner_state_floatbank8_a_air',
        'primary_cleaner_state_floatbank8_a_level',
        'primary_cleaner_state_floatbank8_b_air',
        'primary_cleaner_state_floatbank8_b_level',
        'primary_cleaner_state_floatbank8_c_air',
        'primary_cleaner_state_floatbank8_c_level',
        'primary_cleaner_state_floatbank8_d_air',
        'primary_cleaner_state_floatbank8_d_level',
        'secondary_cleaner_state_floatbank2_a_air',
        'secondary_cleaner_state_floatbank2_a_level',
        'secondary_cleaner_state_floatbank2_b_air',
        'secondary_cleaner_state_floatbank2_b_level',
        'secondary_cleaner_state_floatbank3_a_air',
        'secondary_cleaner_state_floatbank3_a_level',
        'secondary_cleaner_state_floatbank3_b_air',
        'secondary_cleaner_state_floatbank3_b_level',
        'secondary_cleaner_state_floatbank4_a_air',
        'secondary_cleaner_state_floatbank4_a_level',
        'secondary_cleaner_state_floatbank4_b_air',
        'secondary_cleaner_state_floatbank4_b_level',
        'secondary_cleaner_state_floatbank5_a_air',
        'secondary_cleaner_state_floatbank5_a_level',
        'secondary_cleaner_state_floatbank5_b_air',
        'secondary_cleaner_state_floatbank5_b_level',
        'secondary_cleaner_state_floatbank6_a_air',
        'secondary_cleaner_state_floatbank6_a_level',]
          ]

features_train.append( df_train[columns[0]] )
features_train.append( df_train[columns[1]] )
target_train.append( df_train['rougher_output_recovery'] )
target_train.append( df_train['final_output_recovery'] )

features_test.append( df_test[columns[0]] )
features_test.append( df_test[columns[1]] )
target_test.append( df_test['rougher_output_recovery'] )
target_test.append( df_test['final_output_recovery'] )

print(features_train[0].shape)
print(features_train[1].shape)
print(target_train[0].shape)
print(target_train[1].shape)
print(features_test[0].shape)
print(features_test[1].shape)
print(target_test[0].shape)
print(target_test[1].shape)

target_test[0].head(3)
# features_train[0].loc[0,:]
# target_train[0][0]
# df_train[0]
# Out:
# (13433, 22)
# (13433, 30)
# (13433,)
# (13433,)
# (5290, 22)
# (5290, 30)
# (5290,)
# (5290,)
# 0    89.993421
# 1    88.089657
# 2    88.412756
# Name: rougher_output_recovery, dtype: float64

# %% [markdown]
# #### Масштабирование

# %%
features_train[0].loc[0,:]
# Out:
# rougher_input_feed_ag                    6.100378
# rougher_input_feed_pb                    2.284912
# rougher_input_feed_rate                523.546326
# rougher_input_feed_size                 55.486599
# rougher_input_feed_sol                  36.808594
# rougher_input_feed_au                    6.486150
# rougher_input_floatbank10_sulfate       11.986616
# rougher_input_floatbank10_xanthate       6.007990
# rougher_input_floatbank11_sulfate       11.836743
# rougher_input_floatbank11_xanthate       6.005818
# rougher_state_floatbank10_a_air        999.706909
# rougher_state_floatbank10_a_level     -404.066986
# rougher_state_floatbank10_b_air       1603.011353
# rougher_state_floatbank10_b_level     -434.715027
# rougher_state_floatbank10_c_air       1602.375000
# rougher_state_floatbank10_c_level     -442.204468
# rougher_state_floatbank10_d_air       1598.937256
# rougher_state_floatbank10_d_level     -451.294128
# rougher_state_floatbank10_e_air       1404.472046
# ...

# %%
features_train[1].loc[0,:]
# Out:
# primary_cleaner_input_sulfate                  127.092003
# primary_cleaner_input_depressant                10.128295
# primary_cleaner_input_feed_size                  7.250000
# primary_cleaner_input_xanthate                   0.988759
# primary_cleaner_state_floatbank8_a_air        1549.775757
# primary_cleaner_state_floatbank8_a_level      -498.912140
# primary_cleaner_state_floatbank8_b_air        1551.434204
# primary_cleaner_state_floatbank8_b_level      -516.403442
# primary_cleaner_state_floatbank8_c_air        1549.873901
# primary_cleaner_state_floatbank8_c_level      -498.666595
# primary_cleaner_state_floatbank8_d_air        1554.367432
# primary_cleaner_state_floatbank8_d_level      -493.428131
# secondary_cleaner_state_floatbank2_a_air        25.853109
# secondary_cleaner_state_floatbank2_a_level    -498.526489
# secondary_cleaner_state_floatbank2_b_air        23.893660
# secondary_cleaner_state_floatbank2_b_level    -501.406281
# ...

# %%
scaler = []
for i in range(2):
    scaler.append(StandardScaler(with_std=True))
    scaler[i].fit(features_train[i][columns[i]])
    features_train[i].loc[:,columns[i]] = scaler[i].transform(features_train[i])
    features_test[i].loc[:,columns[i]] = scaler[i].transform(features_test[i])
    display(features_train[i].head(1))
    display(features_test[i].head(1))
# Out:
# C:\Users\skysh\.conda\envs\praktikum\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\skysh\.conda\envs\praktikum\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\skysh\.conda\envs\praktikum\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Концентрация металлов
# Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.

# %% [markdown]
# #### Au Золото

# %%
pd.DataFrame( df_train.columns.tolist(), columns=['col'] ).query(
    'col.str.contains("au")', engine='python').sort_values(
    by='col', ascending=True).reset_index(drop=True)
# Out:
#                                                   col
# 0                         final_output_concentrate_au
# 1                                final_output_tail_au
# 2               primary_cleaner_output_concentrate_au
# 3                      primary_cleaner_output_tail_au
# 4                     rougher_calculation_au_pb_ratio
# 5   rougher_calculation_floatbank10_sulfate_to_au_...
# 6   rougher_calculation_floatbank11_sulfate_to_au_...
# 7       rougher_calculation_sulfate_to_au_concentrate
# 8                               rougher_input_feed_au
# 9                       rougher_output_concentrate_au
# 10                             rougher_output_tail_au
# 11                   secondary_cleaner_output_tail_au

# %%
df_tmp_211 = df_train[['rougher_input_feed_au', 'rougher_output_concentrate_au', 
                       'primary_cleaner_output_concentrate_au', 'final_output_concentrate_au', 
                       'secondary_cleaner_output_tail_au', 'final_output_tail_au' ]]
df_tmp_211.head(3)
# Out:
#    rougher_input_feed_au  rougher_output_concentrate_au  \
# 0               6.486150                      19.793808
# 1               6.478583                      20.050975
# 2               6.362222                      19.737170
#
#    primary_cleaner_output_concentrate_au  final_output_concentrate_au  \
# 0                              34.174427                    42.192020
# 1                              34.118526                    42.701629
# 2                              33.969464                    42.657501
#
#    secondary_cleaner_output_tail_au  final_output_tail_au
# 0                          2.606185              2.143149
# 1                          2.488248              2.224930
# 2                          2.458187              2.257889

# %% [markdown]
# Видно, как растёт концентрация золота.
#
# Параметра `secondary_cleaner.output.concentrate_au` не нашлось, но есть параметр `final.output.concentrate_au`.
#
# (Правда, не совсем понятно, например, почему отличаются значения 'secondary_cleaner.output.tail_au' и 'final.output.tail_au', ведь вторичная очистка - это последний этап. Далее то же, более явно, наблюдается для Ag и Pb.)

# %% [markdown]
# Построим график средних значений.

# %%
y = [df_tmp_211.rougher_input_feed_au.mean(), 
     df_tmp_211.rougher_output_concentrate_au.mean(),
     df_tmp_211.primary_cleaner_output_concentrate_au.mean(), 
     df_tmp_211.final_output_concentrate_au.mean()
    ]
y
# Out:
# [7.884886275634052, 19.835033834680313, 32.56309750905874, 44.27748500329106]

# %%
x = ['input', 'rougher', 'first', 'final']
fig, ax = plt.subplots(figsize=(7,4))
plt.plot(x, y, figure=fig, color='gold', marker='o', ls='--', mec='goldenrod')
plt.show();

# %% [markdown]
# Концентрация золота возрастает по этапам почти линейно, от ~8% до ~44%.

# %% [markdown]
# #### Ag Серебро

# %%
pd.DataFrame( df_train.columns.tolist(), columns=['col'] ).query(
    'col.str.contains("ag")', engine='python').sort_values(
    by='col', ascending=True).reset_index(drop=True)
# Out:
#                                      col
# 0            final_output_concentrate_ag
# 1                   final_output_tail_ag
# 2  primary_cleaner_output_concentrate_ag
# 3         primary_cleaner_output_tail_ag
# 4                  rougher_input_feed_ag
# 5          rougher_output_concentrate_ag
# 6                 rougher_output_tail_ag
# 7       secondary_cleaner_output_tail_ag

# %%
df_tmp_212 = df_train[[
    'rougher_input_feed_ag',
    'rougher_output_concentrate_ag',
    'primary_cleaner_output_concentrate_ag',
    'final_output_concentrate_ag',
    
    'secondary_cleaner_output_tail_ag', ##
    'final_output_tail_ag', ##
]]
df_tmp_212.head(3)
# Out:
#    rougher_input_feed_ag  rougher_output_concentrate_ag  \
# 0               6.100378                      11.500771
# 1               6.161113                      11.615865
# 2               6.116455                      11.695753
#
#    primary_cleaner_output_concentrate_ag  final_output_concentrate_ag  \
# 0                               8.547551                     6.055403
# 1                               8.558743                     6.029369
# 2                               8.603505                     6.055926
#
#    secondary_cleaner_output_tail_ag  final_output_tail_ag
# 0                         14.500184             10.411962
# 1                         14.265474             10.462676
# 2                         14.115662             10.507046

# %% [markdown]
# Построим график.

# %%
y = [df_tmp_212.rougher_input_feed_ag.mean(), 
     df_tmp_212.rougher_output_concentrate_ag.mean(),
     df_tmp_212.primary_cleaner_output_concentrate_ag.mean(), 
     df_tmp_212.final_output_concentrate_ag.mean()
    ]
y
# Out:
# [8.58665843042527, 11.98535799423596, 8.236488148031656, 5.1424132394815105]

# %%
#x = ['input', 'rougher', 'first', 'final']
fig, ax = plt.subplots(figsize=(7,4))
plt.plot(x, y, figure=fig, color='silver', marker='o', ls='--', mec='darkgrey')
plt.show();

# %% [markdown]
# Процесс не направлен на получение серебра, и не наблюдается рост его концентрации, даже наоборот.

# %% [markdown]
# #### Pb Свинец

# %%
pd.DataFrame( df_train.columns.tolist(), columns=['col'] ).query(
    'col.str.contains("pb")', engine='python').sort_values(
    by='col', ascending=True).reset_index(drop=True)
# Out:
#                                      col
# 0            final_output_concentrate_pb
# 1                   final_output_tail_pb
# 2  primary_cleaner_output_concentrate_pb
# 3         primary_cleaner_output_tail_pb
# 4        rougher_calculation_au_pb_ratio
# 5                  rougher_input_feed_pb
# 6          rougher_output_concentrate_pb
# 7                 rougher_output_tail_pb
# 8       secondary_cleaner_output_tail_pb

# %%
df_tmp_213 = df_train[[
    'rougher_input_feed_pb',
    'rougher_output_concentrate_pb',
    'primary_cleaner_output_concentrate_pb',
    'final_output_concentrate_pb',
    
    'secondary_cleaner_output_tail_pb', ##
    'final_output_tail_pb', ##
]]
df_tmp_213.head(3)
# Out:
#    rougher_input_feed_pb  rougher_output_concentrate_pb  \
# 0               2.284912                       7.101074
# 1               2.266033                       7.278807
# 2               2.159622                       7.216833
#
#    primary_cleaner_output_concentrate_pb  final_output_concentrate_pb  \
# 0                              10.389648                     9.889648
# 1                              10.497069                     9.968944
# 2                              10.354494                    10.213995
#
#    secondary_cleaner_output_tail_pb  final_output_tail_pb
# 0                          4.694824              0.895447
# 1                          4.592547              0.927452
# 2                          4.624775              0.953716

# %% [markdown]
# Построим график.

# %%
y = [df_tmp_213.rougher_input_feed_pb.mean(), 
     df_tmp_213.rougher_output_concentrate_pb.mean(),
     df_tmp_213.primary_cleaner_output_concentrate_pb.mean(), 
     df_tmp_213.final_output_concentrate_pb.mean()
    ]
y
# Out:
# [3.5125756963292667, 7.808879273799833, 9.661442289330434, 10.17741850112601]

# %%
#x = ['input', 'rougher', 'first', 'final']
fig, ax = plt.subplots(figsize=(7,4))
plt.plot(x, y, figure=fig, color='lightslategrey', marker='o', ls='--', mec='slategrey')
plt.show();

# %% [markdown]
# Концентрация свинца в среднем растёт, нелинейно.

# %% [markdown]
# ### Размеры гранул сырья
# Сравним распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %%
pd.DataFrame( df_train.columns.tolist(), columns=['col'] ).query(
    'col.str.contains("size")', engine='python').sort_values(
    by='col', ascending=False).reset_index(drop=True)
# Out:
#                                col
# 0          rougher_input_feed_size
# 1  primary_cleaner_input_feed_size

# %%
df_tmp_train = df_train[['rougher_input_feed_size', 'primary_cleaner_input_feed_size']]
# df_tmp_train.rename(columns={'rougher_input_feed_size':'feed_size'}, inplace=True)
df_tmp_train.loc[:, 'kind'] = 'train'
# df_tmp_train.head(2)
df_tmp_test = df_train[['rougher_input_feed_size', 'primary_cleaner_input_feed_size']]
df_tmp_test.loc[:, 'kind'] = 'test'
# df_tmp_test.head(2)
# df_tmp_22 = pd.concat([df_tmp_train, df_tmp_test])
# df_tmp_22.head(2)
# Out:
# C:\Users\skysh\.conda\envs\praktikum\lib\site-packages\pandas\core\indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\skysh\.conda\envs\praktikum\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
fig, ax = plt.subplots(figsize=(16,3))

# sns.histplot( df_tmp_22
#             , x='rougher_input_feed_size', hue='kind', stat='density', kde=True
#              , element='step', binwidth=1
#             , common_norm=False, log_scale=False, palette='hsv', fill=True, ax=ax)
##### AttributeError: module 'seaborn' has no attribute 'histplot'
##### seaborn 0.9.0 =(

sns.distplot(a=
             df_tmp_test.query('rougher_input_feed_size <= 120').rougher_input_feed_size.dropna()
             , hist=False, kde=True, color='magenta', ax=ax
            , label='test', kde_kws=dict(alpha=0.9, lw=8))
sns.distplot(a=
             df_tmp_train.query('rougher_input_feed_size <= 120').rougher_input_feed_size.dropna()
             , hist=False, kde=True, color='mediumspringgreen', ax=ax
            , label='train', kde_kws=dict(ls='-', alpha=0.9, lw=3));

# %%
sns.__version__
# print(getmembers(sns, isfunction))
# Out:
# '0.9.0'

# %%
fig, ax = plt.subplots(figsize=(16,3))
sns.distplot(a=
             df_tmp_test.query('5 <= primary_cleaner_input_feed_size <= 10'
                              ).primary_cleaner_input_feed_size.dropna()
             , hist=True, bins=41, norm_hist=True, kde=True, color='magenta', ax=ax
            , label='test', kde_kws=dict(alpha=0.9, lw=8)
            , hist_kws=dict(alpha=0.5))
sns.distplot(a=
             df_tmp_train.query('5 <= primary_cleaner_input_feed_size <= 10'
                               ).primary_cleaner_input_feed_size.dropna()
             , hist=True, bins=41, norm_hist=True, kde=True, color='mediumspringgreen', ax=ax
            , label='train', kde_kws=dict(ls='-', alpha=0.9, lw=3)
            , hist_kws=dict(alpha=0.3));

# %% [markdown]
# Распределения размеров гранул сырья на обучающей и тестовой выборках (на этапах флотации и первичной очистки) практически идентичны, графики совпадают. Здесь не будет негативного влияния на модель.

# %% [markdown]
# ### Суммарная концентрация всех веществ
# Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %%
pd.DataFrame( df_train.columns.tolist(), columns=['col'] ).query(
    'col.str.contains("(concentrate|feed)_(au|ag|pb|sol)", regex=True)',
    engine='python').sort_values(by='col', ascending=False).reset_index(drop=True)
# Out:
#                                        col
# 0           rougher_output_concentrate_sol
# 1            rougher_output_concentrate_pb
# 2            rougher_output_concentrate_au
# 3            rougher_output_concentrate_ag
# 4                   rougher_input_feed_sol
# 5                    rougher_input_feed_pb
# 6                    rougher_input_feed_au
# 7                    rougher_input_feed_ag
# 8   primary_cleaner_output_concentrate_sol
# 9    primary_cleaner_output_concentrate_pb
# 10   primary_cleaner_output_concentrate_au
# 11   primary_cleaner_output_concentrate_ag
# 12            final_output_concentrate_sol
# 13             final_output_concentrate_pb
# 14             final_output_concentrate_au
# 15             final_output_concentrate_ag

# %%
df_tmp_23 = df_train[[
    'rougher_output_concentrate_sol',
    'rougher_output_concentrate_pb',
    'rougher_output_concentrate_au',
    'rougher_output_concentrate_ag',
    'rougher_input_feed_sol',
    'rougher_input_feed_pb',
    'rougher_input_feed_au',
    'rougher_input_feed_ag',
    'primary_cleaner_output_concentrate_sol',
    'primary_cleaner_output_concentrate_pb',
    'primary_cleaner_output_concentrate_au',
    'primary_cleaner_output_concentrate_ag',
    'final_output_concentrate_sol',
    'final_output_concentrate_pb',
    'final_output_concentrate_au',
    'final_output_concentrate_ag',
]]
df_tmp_23 = df_tmp_23.dropna(how='any')   # inplace=True

df_tmp_23.loc[:,'feed_total'] = ( 
#     df_tmp_23['rougher_input_feed_sol'] + 
    df_tmp_23['rougher_input_feed_pb'] 
    + df_tmp_23['rougher_input_feed_au'] + df_tmp_23['rougher_input_feed_ag'] )
df_tmp_23.loc[:,'rougher_total'] = ( 
#     df_tmp_23['rougher_output_concentrate_sol'] + 
    df_tmp_23['rougher_output_concentrate_pb'] 
    + df_tmp_23['rougher_output_concentrate_au'] + df_tmp_23['rougher_output_concentrate_ag'] )
df_tmp_23.loc[:,'primary_total'] = ( 
#     df_tmp_23['primary_cleaner_output_concentrate_sol'] + 
    df_tmp_23['primary_cleaner_output_concentrate_pb'] 
    + df_tmp_23['primary_cleaner_output_concentrate_au'] + df_tmp_23['primary_cleaner_output_concentrate_ag'] )
df_tmp_23.loc[:,'final_total'] = ( 
#     df_tmp_23['final_output_concentrate_sol'] + 
    df_tmp_23['final_output_concentrate_pb'] 
    + df_tmp_23['final_output_concentrate_au'] + df_tmp_23['final_output_concentrate_ag'] )

df_tmp_23.loc[:,['feed_total','rougher_total','primary_total','final_total']].sample(10)
# Out:
#        feed_total  rougher_total  primary_total  final_total
# 2008    16.075700      38.649554      46.567108    57.666020
# 12470   28.015314      38.405028      52.635089    57.193701
# 11818   17.422163      36.367420      50.303815    60.669586
# 8266    18.449172      19.907919      52.036836    58.682847
# 1772    15.560734      35.516800      25.070865    52.978702
# 3597    17.780459      36.109457      52.623313    59.437590
# 12994   23.747974      42.797372      51.999987    57.044307
# 11202   18.695575      39.096813      50.089077    62.118002
# 4484    19.039748      41.406113      52.527095    61.084611
# 4246    23.702525      38.228096      48.111235    60.097885

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
y = [df_tmp_23.feed_total.mean(), 
     df_tmp_23.rougher_total.mean(),
     df_tmp_23.primary_total.mean(), 
     df_tmp_23.final_total.mean()
    ]
y
# Out:
# [19.984120402388594, 39.62927110271611, 50.46102794642084, 59.597316743898595]

# %%
x = ['feed', 'rougher', 'primary', 'final']
with plt.style.context('fivethirtyeight'):
    plt.plot(x, y, color='lightcoral', marker='o', ls='--', mec='hotpink')
plt.show();

# %%
df_tmp_23.loc[:,'feed_wsol'] = df_tmp_23['rougher_input_feed_sol'] + df_tmp_23['feed_total']
df_tmp_23.loc[:,'rougher_wsol'] = df_tmp_23['rougher_output_concentrate_sol'] + df_tmp_23['rougher_total']
df_tmp_23.loc[:,'primary_wsol'] = df_tmp_23['primary_cleaner_output_concentrate_sol'] + df_tmp_23['primary_total']
df_tmp_23.loc[:,'final_wsol'] = df_tmp_23['final_output_concentrate_sol'] + df_tmp_23['final_total']

df_tmp_23.loc[:,['feed_wsol','rougher_wsol','primary_wsol','final_wsol']].sample(10)
# Out:
#        feed_wsol  rougher_wsol  primary_wsol  final_wsol
# 4205   49.990419     73.618202     65.207889   69.384556
# 11589  68.528281     71.771229     66.759850   69.066991
# 8417   49.361248     76.738207     59.180995   68.766463
# 2221   58.515267     76.471403     71.818233   71.286905
# 12468  70.241209     67.101364     43.035292   66.854314
# 7633   56.141885     69.108260     61.403721   68.306018
# 5415   65.749961     76.498117     58.581206   75.647520
# 392    44.885162     69.752964     69.308098   60.566160
# 12283  59.447593     66.784304     62.682258   66.539098
# 6427   59.000519     63.709391     51.232802   70.261573

# %%
y = [df_tmp_23.feed_wsol.mean(), 
     df_tmp_23.rougher_wsol.mean(),
     df_tmp_23.primary_wsol.mean(), 
     df_tmp_23.final_wsol.mean()
    ]
y
# Out:
# [56.453673198994046, 68.53761887889405, 60.519405164771015, 68.73484925164453]

# %%
x = ['feed', 'rougher', 'primary', 'final']
with plt.style.context('Solarize_Light2'):
    plt.plot(x, y, color='blue', marker='o', ls='--', mec='blueviolet')
plt.show();

# %% [markdown]
# Если рассматривать суммарную концентрацию Au, Ag, Pb, то она увеличивается (в основном за счёт увеличения концентрации золота). Если же добавить в сумму Sol (золь(?)), график средних становится ломаным: в среднем сначала увеличивается, затем уменьшается и вновь увеличивается.

# %% [markdown]
# <div class="alert alert-warning"> ⚠️
# <h3> Комментарий ревьюера v1</h3>
#
# Нагляднее было бы построить гистограммы по значения суммарной концетрации веществ по этапам. Так можно увидеть аномальные значения, если они есть

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Функция для sMAPE
# Напишем функцию для вычисления итоговой sMAPE.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def sMAPE(y, pred):
    return 100/len(y) * np.sum(2 * np.abs(pred - y) / (np.abs(y) + np.abs(pred)))

# %%
scorer = make_scorer(sMAPE, greater_is_better=False)
# scorer = make_scorer(mean_absolute_error, greater_is_better=False)
type(scorer)
# Out:
# sklearn.metrics.scorer._PredictScorer

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Обучение моделей, кросс-валидация
# Обучим разные модели и оценим их качество кросс-валидацией. Выберем лучшую модель и проверим её на тестовой выборке.

# %%
stages = ['rougher', 'final']

# %% [markdown]
# #### LinearRegression

# %%
# %%time

params = dict(fit_intercept=[True,False]
              , normalize=[True,False]
             )
model = []
predicted_test = []
smape = []

for i in range(2):
    print(stages[i], ':', sep='')
    model.append(LinearRegression(n_jobs=2))
    grid = GridSearchCV(model[i], params, verbose=0, n_jobs=8, scoring=scorer, cv=4)
    grid.fit(features_train[i], target_train[i])
    
    print(grid.best_params_)
    print('score:', grid.best_score_)
    model[i] = grid.best_estimator_
    print(model[i])
    
    predicted_test.append(model[i].predict(features_test[i]))
    smape.append(sMAPE(target_test[i], predicted_test[i]))
    print(f"Среднее предсказанное recovery на тестовой выборке: {predicted_test[i].mean():3.4f}")
    print(f"Среднее фактическое recovery на тестовой выборке: {target_test[i].mean():3.4f}")
    print(f"sMAPE: {smape[i]:3.2f} %\n")

final_smape = 0.25*smape[0] + 0.75*smape[1]
print(f"\nИтоговое sMAPE на тестовой выборке: {final_smape:3.2f} %\n")
# Out:
# rougher:
# {'fit_intercept': True, 'normalize': False}
# score: -6.65398829519178
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=2, normalize=False)
# Среднее предсказанное recovery на тестовой выборке: 85.9084
# Среднее фактическое recovery на тестовой выборке: 84.9978
# sMAPE: 8.19 %
#
# final:
# {'fit_intercept': True, 'normalize': True}
# score: -9.86629205364095
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=2, normalize=True)
# Среднее предсказанное recovery на тестовой выборке: 67.9754
# Среднее фактическое recovery на тестовой выборке: 68.4715
# sMAPE: 9.68 %
#
#
# Итоговое sMAPE на тестовой выборке: 9.30 %
#
# Wall time: 3.37 s

# %% [markdown]
# #### Ridge

# %%
features_train[0].to_numpy().flags
# Out:
#   C_CONTIGUOUS : False
#   F_CONTIGUOUS : True
#   OWNDATA : False
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
target_train[0].to_numpy().flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : True
#   OWNDATA : False
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
# %%time

params = dict(fit_intercept=[True], #,False],
              normalize=[True], #,False],
              alpha=[0.48, 0.5, 0.54, 0.545],
              tol=[0.001],
              solver=['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga' ],  #, 'lbfgs'
             )
model = []
predicted_test = []
smape = []

for i in range(2):
    print(stages[i], ':', sep='')
    model.append(Ridge(random_state=123746578)) #48756
    grid = GridSearchCV(model[i], params, verbose=0, n_jobs=8, scoring=scorer, cv=4)
    grid.fit( features_train[i].to_numpy().copy(order='C'),
              target_train[i] )
    
    print(grid.best_params_)
    print('score:', grid.best_score_)
    model[i] = grid.best_estimator_
    print(model[i])
    
    predicted_test.append(model[i].predict(features_test[i]))
    smape.append(sMAPE(target_test[i], predicted_test[i]))
    print(f"Среднее предсказанное recovery на тестовой выборке: {predicted_test[i].mean():3.4f}")
    print(f"Среднее фактическое recovery на тестовой выборке: {target_test[i].mean():3.4f}")
    print(f"sMAPE: {smape[i]:3.2f} %\n")

final_smape = 0.25*smape[0] + 0.75*smape[1]
print(f"\nИтоговое sMAPE на тестовой выборке: {final_smape:3.2f} %\n")
# Out:
# rougher:
# {'alpha': 0.48, 'fit_intercept': True, 'normalize': True, 'solver': 'sparse_cg', 'tol': 0.001}
# score: -6.389042390295863
# Ridge(alpha=0.48, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=True, random_state=123746578, solver='sparse_cg', tol=0.001)
# Среднее предсказанное recovery на тестовой выборке: 85.6032
# Среднее фактическое recovery на тестовой выборке: 84.9978
# sMAPE: 7.98 %
#
# final:
# {'alpha': 0.54, 'fit_intercept': True, 'normalize': True, 'solver': 'lsqr', 'tol': 0.001}
# score: -9.408797116193044
# Ridge(alpha=0.54, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=True, random_state=123746578, solver='lsqr', tol=0.001)
# Среднее предсказанное recovery на тестовой выборке: 67.7947
# Среднее фактическое recovery на тестовой выборке: 68.4715
# sMAPE: 9.14 %
#
#
# Итоговое sMAPE на тестовой выборке: 8.85 %
#
# Wall time: 1.97 s

# %% [markdown]
# #### KNeighborsRegressor

# %%
# %%time

model = []
predicted_test = []
smape = []
params = []

for i in range(2):
    print(stages[i], ':', sep='')
    model.append( KNeighborsRegressor(n_jobs=1) )
    
    params.append(dict(n_neighbors=[21,99,125], #125,131,144..154-157,159,164 7.61
                       weights=['uniform'], 
                       p=[1],
                       leaf_size=[1],
                      )
                 )
    params.append(dict(n_neighbors=[67,1812,3001], #899-9.44 #999-9.41 #1812-9.27
                       weights=['uniform'], #,'distance'], 
                       p=[1],
                       leaf_size=[1],
                      )
                 )
    
    grid = GridSearchCV( model[i], params[i], verbose=1, n_jobs=4, scoring=scorer, cv=4 )
    grid.fit(features_train[i], target_train[i])
    
    print(grid.best_params_)
    print('score:', grid.best_score_)
    model[i] = grid.best_estimator_
    print(model[i])
    
    predicted_test.append(model[i].predict(features_test[i]))
    smape.append(sMAPE(target_test[i], predicted_test[i]))
    print(f"Среднее предсказанное recovery на тестовой выборке: {predicted_test[i].mean():3.4f}")
    print(f"Среднее фактическое recovery на тестовой выборке: {target_test[i].mean():3.4f}")
    print(f"sMAPE: {smape[i]:3.2f} %\n")

final_smape = 0.25*smape[0] + 0.75*smape[1]
print(f"\nИтоговое sMAPE на тестовой выборке: {final_smape:3.2f} %\n")
# Out:
# rougher:
# Fitting 4 folds for each of 3 candidates, totalling 12 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  12 out of  12 | elapsed:    9.3s finished
# {'leaf_size': 1, 'n_neighbors': 125, 'p': 1, 'weights': 'uniform'}
# score: -7.927550232105842
# KNeighborsRegressor(algorithm='auto', leaf_size=1, metric='minkowski',
#                     metric_params=None, n_jobs=1, n_neighbors=125, p=1,
#                     weights='uniform')
# Среднее предсказанное recovery на тестовой выборке: 86.6564
# Среднее фактическое recovery на тестовой выборке: 84.9978
# sMAPE: 7.61 %
#
# final:
# Fitting 4 folds for each of 3 candidates, totalling 12 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  12 out of  12 | elapsed:  1.8min finished
# {'leaf_size': 1, 'n_neighbors': 1812, 'p': 1, 'weights': 'uniform'}
# score: -9.759211307597225
# ...

# %% [markdown]
# #### SVR

# %%
# %%time

model = []
predicted_test = []
smape = []
params = []

for i in range(2):
    print(stages[i], ':', sep='')
    model.append(SVR())
    
    params.append(dict(kernel=['linear'], #,'poly','rbf'
                      gamma=['scale'], #,'auto'],
#                        degree=[2,3],
#                       coef0=[0.0, 0.1],
                      tol=[1e-3],
                      C=[1.09, 1.1],
                      epsilon=[0.8, 0.81],
                      )
                 )
    params.append(dict(kernel=['rbf'], #,,'linear','poly'
                       gamma=['auto'], #'scale',
#                        degree=[3,4],
#                        coef0=[0.0, 0.1],
                       tol=[1e-3],
                       C=[0.8, 0.85],
                       epsilon=[0.49, 0.5],
                      )
                 )
    
    grid = GridSearchCV(model[i], params, verbose=1, n_jobs=8, scoring=scorer, cv=4)
    grid.fit(features_train[i], target_train[i])
    
    print(grid.best_params_)
    print('score:', grid.best_score_)
    model[i] = grid.best_estimator_
    print(model[i])
    
    predicted_test.append(model[i].predict(features_test[i]))
    smape.append(sMAPE(target_test[i], predicted_test[i]))
    print(f"Среднее предсказанное recovery на тестовой выборке: {predicted_test[i].mean():3.4f}")
    print(f"Среднее фактическое recovery на тестовой выборке: {target_test[i].mean():3.4f}")
    print(f"sMAPE: {smape[i]:3.2f} %\n")

final_smape = 0.25*smape[0] + 0.75*smape[1]
print(f"\nИтоговое sMAPE на тестовой выборке: {final_smape:3.2f} %\n")
# Out:
# rougher:
# Fitting 4 folds for each of 8 candidates, totalling 32 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  32 out of  32 | elapsed:  1.5min finished
# {'C': 1.09, 'epsilon': 0.81, 'gamma': 'scale', 'kernel': 'linear', 'tol': 0.001}
# score: -6.722639145517822
# SVR(C=1.09, cache_size=200, coef0=0.0, degree=3, epsilon=0.81, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# Среднее предсказанное recovery на тестовой выборке: 86.3404
# Среднее фактическое recovery на тестовой выборке: 84.9978
# sMAPE: 7.91 %
#
# final:
# Fitting 4 folds for each of 16 candidates, totalling 64 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=8)]: Done  64 out of  64 | elapsed:  3.7min finished
# {'C': 0.85, 'epsilon': 0.5, 'gamma': 'auto', 'kernel': 'rbf', 'tol': 0.001}
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Были получены следующие значения sMAPE на тестовой выборке:
#
# - `LinearRegression:     9.30 %`
# - `Ridge:                8.85 %`
# - `KNeighborsRegressor:  8.86 %`
# - `SVR:                  9.61 %`
#
# Лучшей моделью в данном случае оказалась `Ridge regression` (ридж-регрессия или гребневая регрессия), как и самой быстрой.
# <br>*Это один из методов понижения размерности. Часто его применяют для борьбы с переизбыточностью данных, когда независимые переменные коррелируют друг с другом (т.е. имеет место мультиколлинеарность).*
#
# За ней с минимальным отставанием идёт `KNeighborsRegressor`.

# %%
dt.datetime.today().strftime("%d.%m.%Y %H:%M")
# Out:
# '26.06.2022 23:54'

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке выполнения
# - [x]  Выполнен шаг 1: данные подготовлены
#     - [x]  Проверена формула вычисления эффективности обогащения
#     - [x]  Проанализированы признаки, недоступные в тестовой выборке
#     - [x]  Проведена предобработка данных
# - [x]  Выполнен шаг 2: данные проанализированы
#     - [x]  Исследовано изменение концентрации элементов на каждом этапе
#     - [x]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [x]  Исследованы суммарные концентрации
# - [x]  Выполнен шаг 3: построена модель прогнозирования
#     - [x]  Написана функция для вычисления итогового *sMAPE*
#     - [x]  Обучено и проверено несколько моделей
#     - [x]  Выбрана лучшая модель, её качество проверено на тестовой выборке
